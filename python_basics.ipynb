# %%
# !python --version
# Out:
# Python 3.12.12

# %%
x=3
print(x,type(x))
print(x+1)
print(x-1)
print(x*2)
print(x**2)
# Out:
# 3 <class 'int'>
# 4
# 2
# 6
# 9

# %%
print(len("Hello"))
# Out:
# 5

# %%
var1="Hello"
var2="World"
addupstr='{} {} {}'.format(var2,var1,114514)
print(addupstr)
# Out:
# World Hello 114514

# %%
list=[1,2,3,4,5]
print(list[::2])
# Out:
# [1, 3, 5]
